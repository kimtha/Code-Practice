# %%
import pandas as pd

# %%
df=pd.read_csv("./data/FEV_data.csv")

# %%
df
# Out:
#      age    FEV    ht     sex smoke               comments
# 0      9  1.708  57.0  Female    No  Equipment malfunction
# 1      8  1.724  67.5  Female    No                    NaN
# 2      7  1.720  54.5  Female    No  Equipment malfunction
# 3      9  1.558  53.0    Male    No                    NaN
# 4      9  1.895  57.0    Male    No                    NaN
# 5      8  2.336  61.0  Female    No                    NaN
# 6      6  1.919  58.0  Female    No                    NaN
# 7      6  1.415  56.0  Female    No                    NaN
# 8      8  1.987  58.5  Female    No                    NaN
# 9      9  1.942  60.0  Female    No                    NaN
# 10     6  1.602  53.0  Female    No                    NaN
# 11     8  1.735  54.0    Male    No                    NaN
# 12     8  2.193  58.5  Female    No                    NaN
# 13     8  2.118  60.5    Male    No                    NaN
# 14     8  2.258  58.0    Male    No                    NaN
# ...

# %%
df.head()
# Out:
#    age    FEV    ht     sex smoke               comments
# 0    9  1.708  57.0  Female    No  Equipment malfunction
# 1    8  1.724  67.5  Female    No                    NaN
# 2    7  1.720  54.5  Female    No  Equipment malfunction
# 3    9  1.558  53.0    Male    No                    NaN
# 4    9  1.895  57.0    Male    No                    NaN

# %%
df.tail()
# Out:
#      age    FEV    ht     sex smoke comments
# 649   16  4.270  67.0    Male   Yes      NaN
# 650   15  3.727  68.0    Male   Yes      NaN
# 651   18  2.853  60.0  Female    No      NaN
# 652   16  2.795  63.0  Female   Yes      NaN
# 653   15  3.211  66.5  Female    No      NaN

# %%
df.columns
# Out:
# Index(['age', 'FEV', 'ht', 'sex', 'smoke', 'comments'], dtype='object')

# %%
df["age"]
# Out:
# 0       9
# 1       8
# 2       7
# 3       9
# 4       9
# 5       8
# 6       6
# 7       6
# 8       8
# 9       9
# 10      6
# 11      8
# 12      8
# 13      8
# 14      8
# 15      7
# 16      5
# 17      6
# 18      9
# 19      9
# 20      5
# 21      5
# 22      4
# 23      7
# 24      9
# 25      3
# 26      9
# 27      5
# 28      8
# 29      9
#        ..
# 624    15
# 625    18
# 626    17
# 627    15
# 628    17
# 629    17
# 630    16
# 631    17
# 632    15
# 633    15
# 634    16
# 635    16
# 636    15
# 637    18
# 638    15
# 639    16
# 640    17
# 641    16
# 642    16
# 643    15
# 644    18
# 645    15
# 646    16
# 647    17
# 648    16
# 649    16
# 650    15
# 651    18
# 652    16
# 653    15
# Name: age, Length: 654, dtype: int64

# %%
import numpy as np

# %%
np.median(df["age"])
# Out:
# 10.0

# %%
df.describe(include="all")
# Out:
#                age         FEV          ht   sex smoke               comments
# count   654.000000  654.000000  654.000000   654   654                      2
# unique         NaN         NaN         NaN     2     2                      1
# top            NaN         NaN         NaN  Male    No  Equipment malfunction
# freq           NaN         NaN         NaN   336   589                      2
# mean      9.931193    2.636780   61.143578   NaN   NaN                    NaN
# std       2.953935    0.867059    5.703513   NaN   NaN                    NaN
# min       3.000000    0.791000   46.000000   NaN   NaN                    NaN
# 25%       8.000000    1.981000   57.000000   NaN   NaN                    NaN
# 50%      10.000000    2.547500   61.500000   NaN   NaN                    NaN
# 75%      12.000000    3.118500   65.500000   NaN   NaN                    NaN
# max      19.000000    5.793000   74.000000   NaN   NaN                    NaN

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x=df["age"]

# %%
y=df["FEV"]

# %%
plt.scatter(x,y)

# %%
c=df["height"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'height'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
c=df["ht"]

# %%
plt.scatter(x,c)

# %%
df=pd.read_csv("./data/190626-01-A-bottom.csv")

# %%
df.head()
# Out:
#    frames  interpolated  measurement_x  measurement_y  objid  position_x  \
# 0       2           NaN          213.0          101.0    NaN       213.0
# 1       3           NaN          213.0          101.0    NaN       213.0
# 2       4           NaN          213.0          101.0    NaN       213.0
# 3       5           NaN          213.0          101.0    NaN       213.0
# 4       6           NaN          213.0          101.0    NaN       213.0
#
#    position_y  pixel_width  pixel_height  manual_tracker_fix
# 0       101.0          554           238                True
# 1       101.0          554           238                True
# 2       101.0          554           238                True
# 3       101.0          554           238                True
# 4       101.0          554           238                True

# %%
x=df["position_x"]
y=df["position_y"]

# %%
plt.scatter(x,y)

# %%
fig=plt.figure(figsize=(4,2))
ax=fig.add_subplot(1,1,1)
ax.scatter(x,y,s=2)
ax.set_xlim(0,w)
ax.set_ylim(0,h)
ax.plot(x,y)

# %%
w=df["pixel_width"]
np.mean(df["pixel_width"])
w=np.mean(df["pixel_width"])

# %%
print(w)
# Out:
# 554.0

# %%
np.mean(w)
# Out:
# 554.0

# %%
h=df["pixel_height"]

# %%
np.mean(df["pixel_height"])
h=np.mean(df["pixel_height"])

# %%
print(h)
# Out:
# 238.0
